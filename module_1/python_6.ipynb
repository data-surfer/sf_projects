# %% [markdown]
# # Python-6

# %%
#6.1

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sf.csv')

# %%
small_df = df[df.columns[1:8]].head(25)
small_df
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Germany      3
# Uruguay      3
# Belgium      3
# Argentina    3
# France       2
# Croatia      1
# Italy        1
# Poland       1
# Slovenia     1
# Portugal     1
# England      1
# Brazil       1
# Name: Nationality, dtype: int64

# %%
s.loc[s > 1]
# Out:
# Spain        4
# Germany      3
# Uruguay      3
# Belgium      3
# Argentina    3
# France       2
# Name: Nationality, dtype: int64

# %%
len(df['Club'].value_counts())
# Out:
# 650

# %%
df['Position'].value_counts(normalize = True)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# RF     0.000465
# LAM    0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
df['Position'].value_counts(normalize = True)>0.1
# Out:
# GK      True
# ST      True
# CB      True
# CM     False
# LB     False
# RB     False
# RM     False
# LM     False
# CDM    False
# CAM    False
# RCB    False
# LCB    False
# LW     False
# RCM    False
# RW     False
# LCM    False
# LDM    False
# RDM    False
# LS     False
# RS     False
# RWB    False
# LWB    False
# CF     False
# LF     False
# RF     False
# LAM    False
# RAM    False
# Name: Position, dtype: bool

# %%
df['Position'].value_counts(normalize = True)<0.01
# Out:
# GK     False
# ST     False
# CB     False
# CM     False
# LB     False
# RB     False
# RM     False
# LM     False
# CDM    False
# CAM    False
# RCB    False
# LCB    False
# LW     False
# RCM    False
# RW     False
# LCM    False
# LDM    False
# RDM    False
# LS      True
# RS      True
# RWB     True
# LWB     True
# CF      True
# LF      True
# RF      True
# LAM     True
# RAM     True
# Name: Position, dtype: bool

# %%
df['Wage'].value_counts(bins=4)
# Out:
# (435.999, 142000.0]     12818
# (142000.0, 283000.0]       61
# (283000.0, 424000.0]       16
# (424000.0, 565000.0]        2
# Name: Wage, dtype: int64

# %%
df['Wage']
# Out:
# 0        565000
# 1        405000
# 2        290000
# 3        260000
# 4        355000
#           ...
# 12892      1000
# 12893      1000
# 12894      1000
# 12895      1000
# 12896      1000
# Name: Wage, Length: 12897, dtype: int64

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
s.index[3].left
# Out:
# 447250.0

# %%
s.index.right
# Out:
# Float64Index([329500.0, 211750.0, 447250.0, 565000.0], dtype='float64')

# %%
s
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
df['FKAccuracy'].value_counts()
# Out:
# 32    382
# 35    361
# 42    355
# 40    353
# 39    343
#      ...
# 90      1
# 93      1
# 94      1
# 92      1
# 91      1
# Name: FKAccuracy, Length: 89, dtype: int64

# %%
df['FKAccuracy'].value_counts(normalize = True)
# Out:
# count    89.000000
# mean      0.011236
# std       0.008630
# min       0.000078
# 25%       0.002869
# 50%       0.009925
# 75%       0.016360
# max       0.029619
# Name: FKAccuracy, dtype: float64

# %%
df['FKAccuracy'].value_counts()#.tail(20)
# Out:
# 32    382
# 35    361
# 42    355
# 40    353
# 39    343
#      ...
# 90      1
# 93      1
# 94      1
# 92      1
# 91      1
# Name: FKAccuracy, Length: 89, dtype: int64

# %%
df['FKAccuracy'].value_counts(bins=5)#.tail(20)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %% [markdown]
# ### 5.5

# %%
df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Switzerland', 'Norway', 'DR Congo', 'Ukraine',
#        'Mexico', 'Czech Republic', 'Ivory Coast', 'Albania', 'Turkey',
#        'Ghana', 'Ecuador', 'Mali', 'Nigeria', 'Dominican Republic',
#        'Japan', 'Cameroon', 'Republic of Ireland', 'Romania',
#        'United States', 'Russia', 'Hungary', 'Iceland', 'Zimbabwe',
#        'Togo', 'Angola', 'Burkina Faso', 'Peru', 'Scotland', 'Venezuela',
#        'Estonia', 'Tunisia', 'Israel', 'Equatorial Guinea', 'New Zealand',
# ...

# %%
len(df['Nationality'].unique())
# Out:
# 156

# %%
# Подсчет кол-ва уникальных значений
small_df['Nationality'].nunique()
# Out:
# 13

# %%
# Преобразование результатов value_counts() в ДатаФрейм
s_df = df['FKAccuracy'].value_counts().reset_index()

# %%
# Тоже самое
s = df['Nationality'].value_counts()
s_df = s.reset_index()
display(s_df)
# Out:
#            index  Nationality
# 0        England         1368
# 1        Germany          919
# 2          Spain          671
# 3         France          614
# 4      Argentina          574
# ..           ...          ...
# 151       Rwanda            1
# 152    Palestine            1
# 153  Philippines            1
# 154        Malta            1
# 155      Grenada            1
#
# [156 rows x 2 columns]

# %%
s_df.columns = ['Nationality','Players Count']
display(s_df)
# Out:
#      Nationality  Players Count
# 0        England           1368
# 1        Germany            919
# 2          Spain            671
# 3         France            614
# 4      Argentina            574
# ..           ...            ...
# 151       Rwanda              1
# 152    Palestine              1
# 153  Philippines              1
# 154        Malta              1
# 155      Grenada              1
#
# [156 rows x 2 columns]

# %%
df.Wage.value_counts(bins=4)
# Out:
# (435.999, 142000.0]     12818
# (142000.0, 283000.0]       61
# (283000.0, 424000.0]       16
# (424000.0, 565000.0]        2
# Name: Wage, dtype: int64

# %%
df[(df.Nationality == 'Spain')&(df.Wage<565000)&(df.Wage >242000)]


# &\
#    (df.Wage <.value_counts())]
# Out:
#     Unnamed: 0             Name  Age Nationality               Club     Value  \
# 3            3           De Gea   27       Spain  Manchester United  72000000
# 8            8     Sergio Ramos   32       Spain        Real Madrid  51000000
# 13          13      David Silva   32       Spain    Manchester City  60000000
# 20          20  Sergio Busquets   29       Spain       FC Barcelona  51500000
# 30          30             Isco   26       Spain        Real Madrid  73500000
# 49          49       Jordi Alba   29       Spain       FC Barcelona  38000000
#
#       Wage Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 3   260000       GK        17         13  ...         40         68       15
# 8   380000      RCB        66         60  ...         75         82       87
# 13  285000      LCM        84         76  ...         75         93       59
# 20  315000      CDM        62         67  ...         60         90       90
# ...

# %%
df.Wage.value_counts(normalize = True)<0.25
# Out:
# 1000      False
# 2000       True
# 3000       True
# 4000       True
# 5000       True
#           ...
# 420000     True
# 405000     True
# 200000     True
# 290000     True
# 300000     True
# Name: Wage, Length: 142, dtype: bool

# %%
df.Wage.value_counts(normalize = True)
# Out:
# 1000      0.356750
# 2000      0.205629
# 3000      0.123750
# 4000      0.072032
# 5000      0.043886
#             ...
# 420000    0.000078
# 405000    0.000078
# 200000    0.000078
# 290000    0.000078
# 300000    0.000078
# Name: Wage, Length: 142, dtype: float64

# %% [markdown]
# ### 6.6

# %%
#6.6.1
df_spain = df[df.Nationality == 'Spain']
df_wage = df_spain.Wage.value_counts(bins=4)

# %%
df_wage
# Out:
# (620.999, 95750.0]      651
# (95750.0, 190500.0]      11
# (190500.0, 285250.0]      6
# (285250.0, 380000.0]      3
# Name: Wage, dtype: int64

# %%
df_spain25 = df_spain[(df_spain.Wage>df_wage.index[0].left)\
   &(df_spain.Wage <df_wage.index[0].right)]

# %%
#Result
len(df_spain25)/len(df_spain)
# Out:
# 0.970193740685544

# %%
#6.6.2
df_club = df[df.Club == "Manchester United"]

# %%
df_club.Nationality.nunique()
# Out:
# 13

# %%
#6.6.3
df_nationality = df[(df.Club == 'Juventus')&(df.Nationality == 'Brazil')]

# %%
df_nationality.Name.unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
### Вариант в одну строку
df[(df.Club == 'Juventus')&(df.Nationality == 'Brazil')].Name.unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
#6.6.4
df[(df.Age > 35)].Club.value_counts()
# Out:
# Club Atlético Huracán         4
# Hokkaido Consadole Sapporo    4
# Nagoya Grampus                3
# Hammarby IF                   3
# Club Atlético Talleres        3
#                              ..
# Crystal Palace                1
# Grimsby Town                  1
# Walsall                       1
# SPAL                          1
# Cerezo Osaka                  1
# Name: Club, Length: 212, dtype: int64

# %%
#6.6.5
df[(df.Nationality == 'Argentina')].Age.value_counts(bins=4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
#6.6.6
df[(df.Nationality == 'Spain')]\
.Age.value_counts(normalize = True).loc[21]
# Out:
# 0.11773472429210134

# %% [markdown]
# ### 6.7

# %%
df.groupby(['Club'])

# %%
grouped_df = df.groupby(['Club']).sum()
display(grouped_df)
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
grouped_df.loc['Ajax']#['Wage']
# Out:
# Unnamed: 0             26041
# Age                      275
# Value              152250000
# Wage                  158000
# Crossing                 844
# Finishing                723
# HeadingAccuracy          848
# ShortPassing             940
# Volleys                  696
# Dribbling                932
# Curve                    779
# FKAccuracy               680
# LongPassing              878
# BallControl              951
# Acceleration             944
# SprintSpeed              969
# Agility                  969
# Reactions                924
# Balance                  918
# ShotPower                876
# Jumping                  915
# Stamina                  974
# Strength                 896
# LongShots                720
# Aggression               847
# Interceptions            801
# Positioning              813
# Vision                   881
# Penalties                710
# Composure                929
# Marking                  750
# StandingTackle           814
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
display(grouped_df.head(5))

## дополнительный параметр ascending=False, который указывает, 
## что данные надо сортировать по убыванию.
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %%
df.groupby(['Position'])['Wage'].sum()\
           .sort_values(ascending = False)>5000000
# Out:
# Position
# ST      True
# GK      True
# CB      True
# CM      True
# LB      True
# CAM     True
# LM      True
# RM      True
# RB      True
# CDM    False
# RCB    False
# LCB    False
# RW     False
# RCM    False
# LCM    False
# LW     False
# LS     False
# RDM    False
# RS     False
# LDM    False
# RF     False
# LF     False
# RWB    False
# LAM    False
# LWB    False
# CF     False
# RAM    False
# Name: Wage, dtype: bool

# %%
grouped_df
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']]\
.mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
df.loc[df.Nationality == "Dominican Republic"]\
[['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %% [markdown]
# ## 6.8

# %%
# 6.8.1

round(df.groupby(['Position'])[['Wage','Value']]\
.mean().sort_values(['Value'],ascending=False ))
# Out:
#               Wage       Value
# Position
# LF         75125.0  27362500.0
# RF        119000.0  26365833.0
# LAM        61000.0  13245833.0
# RAM        11800.0   8345000.0
# LS         15421.0   5848430.0
# LCM        13498.0   4318090.0
# RCM        13504.0   4217604.0
# RS         13482.0   3645833.0
# LW         12169.0   3603099.0
# RW         13823.0   3495738.0
# LDM        10243.0   3369459.0
# RCB        11270.0   3009055.0
# CAM         8689.0   2963199.0
# RDM        11283.0   2692717.0
# LCB         9753.0   2636516.0
# LM          7473.0   2466174.0
# ST          7853.0   2157252.0
# RM          6655.0   2138734.0
# LWB         5783.0   1931333.0
# CF          4863.0   1848627.0
# CDM         7122.0   1658900.0
# CM          5805.0   1617465.0
# RWB         6000.0   1555571.0
# GK          5353.0   1502502.0
# LB          6084.0   1429032.0
# CB          5329.0   1321251.0
# RB          5310.0   1248940.0

# %% [markdown]
# ## 6.9

# %%
df.groupby(['Nationality'])[['Club','Name']].nunique()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        26    29
# Algeria        33    37
# Andorra         1     1
# Angola          9    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      34    36
# Wales          56   101
# Zambia          5     6
# Zimbabwe        8     9
#
# [156 rows x 2 columns]

# %%
df.groupby(['Nationality'])[['Club','Name']].count()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        29    29
# Algeria        37    37
# Andorra         1     1
# Angola         10    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      36    36
# Wales         102   102
# Zambia          6     6
# Zimbabwe        9     9
#
# [156 rows x 2 columns]

# %%
df.groupby(['Club'])['Name'].count()
# Out:
# Club
#  SSV Jahn Regensburg     24
# 1. FC Heidenheim 1846    20
# 1. FC Kaiserslautern     23
# 1. FC Köln               10
# 1. FC Magdeburg          21
#                          ..
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          22
# Örebro SK                26
# Östersunds FK            20
# Śląsk Wrocław            24
# Name: Name, Length: 650, dtype: int64

# %%
df.groupby(['Club'])['Dribbling'].median()
# Out:
# Club
#  SSV Jahn Regensburg     57.5
# 1. FC Heidenheim 1846    59.5
# 1. FC Kaiserslautern     54.0
# 1. FC Köln               60.5
# 1. FC Magdeburg          53.0
#                          ...
# Zagłębie Sosnowiec       58.0
# Çaykur Rizespor          62.0
# Örebro SK                55.0
# Östersunds FK            61.5
# Śląsk Wrocław            54.5
# Name: Dribbling, Length: 650, dtype: float64

# %%
# Подсказка: чтобы в процессе группировки применить
# к данным одновременно две агрегирующие функции, 
# необходимо указать их как аргументы метода agg:

# df.groupby(столбец_для_группировки)[столбцы_для_отображения]
# .agg(['функция_1', 'функция_2'])



df_wage_mean = df.groupby(['Club'])['Wage'].agg(['mean','median'])

# %%
# Out:
# 0

# %%
df1 = df.groupby(['Club'])['Wage'].agg(['mean','median'])

# %%
df1.describe()
# Out:
#                 mean         median
# count     650.000000     650.000000
# mean     8296.997931    7425.384615
# std     17839.974855   17729.026592
# min      1000.000000    1000.000000
# 25%      1904.761905    1500.000000
# 50%      2978.260870    2000.000000
# 75%      7218.531469    5000.000000
# max    188090.909091  207500.000000

# %%
df1.columns = ['Mean','Median']

# %%
df1
# Out:
#                               Mean  Median
# Club
#  SSV Jahn Regensburg   3750.000000    3500
# 1. FC Heidenheim 1846  3800.000000    3000
# 1. FC Kaiserslautern   1434.782609    1000
# 1. FC Köln             9200.000000    4000
# 1. FC Magdeburg        4000.000000    4000
# ...                            ...     ...
# Zagłębie Sosnowiec     1080.000000    1000
# Çaykur Rizespor        5363.636364    4500
# Örebro SK              1384.615385    1000
# Östersunds FK          1950.000000    1000
# Śląsk Wrocław          2083.333333    2000
#
# [650 rows x 2 columns]

# %%
df1[df1.Mean ==  df1.Median].count()
# Out:
# Mean      52
# Median    52
# dtype: int64

# %%
df1[df1.Mean ==  df1.Median]
# Out:
#                            Mean  Median
# Club
# 1. FC Magdeburg          4000.0    4000
# AEK Athens               1000.0    1000
# AJ Auxerre               2000.0    2000
# Benevento                2000.0    2000
# Bohemian FC              1000.0    1000
# Boyacá Chicó FC          1000.0    1000
# Bray Wanderers           1000.0    1000
# Brøndby IF               6000.0    6000
# CD Feirense              4000.0    4000
# CD Tondela               2000.0    2000
# Cork City                1000.0    1000
# Cruzeiro                13000.0   13000
# Deportivo Pasto          1000.0    1000
# Dinamo Zagreb            1000.0    1000
# Dundalk                  1000.0    1000
# Dynamo Kyiv              1000.0    1000
# Envigado FC              1000.0    1000
# FC Energie Cottbus       1000.0    1000
# FC Metz                  1500.0    1500
# Grimsby Town             2000.0    2000
# Göztepe SK               7000.0    7000
# HJK Helsinki             1000.0    1000
# ...

# %%
df1[df1.Mean == df1.Median].max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-549-a79823df561a> in <module>
# ----> 1 df1[df1.Mean == df1.Median].max().value()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
df1 = df1[(df1.Mean == df1.Median)]

# %%
df1[df1.Mean ==  df1.Median].max().describe()
# Out:
# count        2.0
# mean     13000.0
# std          0.0
# min      13000.0
# 25%      13000.0
# 50%      13000.0
# 75%      13000.0
# max      13000.0
# dtype: float64

# %%
df1[df1.Mean == df1.Mean.max()]
# Out:
#              Mean  Median
# Club
# Cruzeiro  13000.0   13000

# %% [markdown]
# # 6.10

# %%
### 6.10.1
df.groupby(['Club'])['Wage'].sum().loc['Chelsea']
# Out:
# 2035000

# %%
### 6.10.2
df[(df.Nationality == 'Argentina')&(df.Age == 20)].Wage.max()
# Out:
# 54000

# %%
## 6.10.3
df[(df.Nationality == 'Argentina')&(df.Age == 30)].Wage.max()
# Out:
# 300000

# %%
## 6.10.4
df[(df.Nationality == 'Argentina')&(df.Age == 30)].Wage.min()
# Out:
# 1000

# %%
## 6.10.5
df5 = df[(df.Nationality == 'Argentina')]
df5.groupby(['Club'])[['Strength','Balance']].max().loc['FC Barcelona']
# Out:
# Strength    59
# Balance     95
# Name: FC Barcelona, dtype: int64

# %%
df[(df.Nationality == 'Argentina')&(df.Club == 'FC Barcelona')]\
.Strength.max()
# Out:
# 59

# %% [markdown]
# ## 6.12

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])]\
.pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum')
display(pivot)
# Out:
#                            Wage
# Club               FC Barcelona  Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0  205000.0          206000.0         NaN
# Belgium                110000.0       NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN  180000.0               NaN         NaN
# Brazil                 465000.0  335000.0           91000.0    570000.0
# Chile                  205000.0       NaN          215000.0         NaN
# Costa Rica                  NaN       NaN               NaN    195000.0
# Croatia                260000.0  160000.0               NaN    420000.0
# Dominican Republic          NaN       NaN               NaN    140000.0
# Ecuador                     NaN       NaN          120000.0         NaN
# England                     NaN       NaN          478000.0         NaN
# France                 495000.0  145000.0          375000.0    459000.0
# ...

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True)
display(pivot)
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %% [markdown]
# ## 6.13

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
pivot.loc['Argentina']['Name']['Manchester United']
# Out:
# 2

# %%
## 6.13.1
pivot = df.pivot_table(values=['Name'],
index=['Position'],
columns=['Club'],
aggfunc='count',
fill_value=0)
display(pivot)
# Out:
#                          Name                                             \
# Club      SSV Jahn Regensburg 1. FC Heidenheim 1846 1. FC Kaiserslautern
# Position
# CAM                         0                     1                    0
# CB                          5                     3                    3
# CDM                         1                     0                    3
# CF                          0                     0                    0
# CM                          2                     1                    0
# GK                          3                     2                    3
# LAM                         0                     0                    0
# LB                          2                     2                    2
# LCB                         0                     1                    1
# LCM                         0                     0                    0
# LDM                         1                     0                    0
# ...

# %%
round(pivot.loc['GK'].mean(),3)
# Out:
# 2.525

# %%
## 6.13.2
df1 = pivot.loc['CM']

# %%
df1.value_counts()
# Out:
# 1    211
# 2    149
# 0    136
# 3     89
# 4     39
# 5     21
# 6      5
# Name: CM, dtype: int64

# %% [markdown]
# ## 6.14

# %%
##6.14.1
pivot = df.pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
fill_value=0)
display(pivot)
# Out:
#                             Wage                                             \
# Club         SSV Jahn Regensburg 1. FC Heidenheim 1846 1. FC Kaiserslautern
# Nationality
# Afghanistan                    0                     0                    0
# Albania                        0                     0                    0
# Algeria                        0                     0                    0
# Andorra                        0                     0                    0
# Angola                         0                     0                    0
# ...                          ...                   ...                  ...
# Uzbekistan                     0                     0                    0
# Venezuela                      0                     0                    0
# Wales                          0                     0                    0
# Zambia                         0                     0                    0
# ...

# %%
pivot.loc['Russia']['Wage']['AS Monaco'].sum()
# Out:
# 61000

# %%
##6.14.2
pivot = df.pivot_table(values=['SprintSpeed'],
index=['Position'],
columns=['Club'],
aggfunc='mean',
fill_value=0,
margins=True,
)
display(pivot)
# Out:
#                   SprintSpeed                                             \
# Club      SSV Jahn Regensburg 1. FC Heidenheim 1846 1. FC Kaiserslautern
# Position
# CAM                  0.000000             68.000000             0.000000
# CB                  46.600000             61.333333            59.000000
# CDM                 82.000000              0.000000            65.666667
# CF                   0.000000              0.000000             0.000000
# CM                  61.000000             68.000000             0.000000
# GK                  33.000000             41.000000            42.666667
# LAM                  0.000000              0.000000             0.000000
# LB                  76.000000             60.000000            68.000000
# LCB                  0.000000             55.000000            45.000000
# LCM                  0.000000              0.000000             0.000000
# LDM                 55.000000              0.000000             0.000000
# ...

# %%
result = pivot.sort_values(('SprintSpeed', 'All'), ascending=False)

# %%
result
# Out:
#                   SprintSpeed                                             \
# Club      SSV Jahn Regensburg 1. FC Heidenheim 1846 1. FC Kaiserslautern
# Position
# LAM                  0.000000              0.000000             0.000000
# RF                   0.000000              0.000000             0.000000
# LF                   0.000000              0.000000             0.000000
# RW                   0.000000              0.000000             0.000000
# RM                   0.000000             78.333333            82.500000
# LW                   0.000000              0.000000            80.000000
# LM                  76.000000             69.500000            70.500000
# RAM                 78.000000              0.000000             0.000000
# RWB                  0.000000              0.000000             0.000000
# LWB                  0.000000              0.000000             0.000000
# LS                   0.000000              0.000000            85.000000
# ...

# %%
##6.14.3
pivot.loc['ST'].sort_values(ascending=False)
# Out:
#              Club
# SprintSpeed  Vitória           91.000000
#              Sydney FC         88.000000
#              CD Lugo           87.000000
#              Brøndby IF        84.666667
#              Leicester City    84.500000
#                                  ...
#              BK Häcken          0.000000
#              Spartak Moscow     0.000000
#              BSC Young Boys     0.000000
#              Benevento          0.000000
#              FC Barcelona       0.000000
# Name: ST, Length: 651, dtype: float64
